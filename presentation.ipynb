# %% [markdown]
# # Presentation Notebook

# %% [markdown]
# ## import

# %%
import sys
sys.path.append("sources")

from Doodler import *
import Data_generator
import utils
import Network

import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data generator

# %% [markdown]
# ### Generation of the "big" dataset

# %%
generator = Data_generator.Data_generator(number_data=800, n=25, noise=0, tr_size=0.63, test_size=0.25, wr=[0.2,0.7], hr=[0.2,0.7], flat=False,random_seed = 42)
data = generator.generate_data(return_data=True)
generator.save_data("data/1")
plt.hist(data[0][2], bins=50)
# Out:
# Data saved at :  data/1
# (array([46.,  0.,  0.,  0.,  0.,  0., 61.,  0.,  0.,  0.,  0.,  0., 44.,
#          0.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0.,  0.,  0.,  0., 61.,
#          0.,  0.,  0.,  0.,  0., 67.,  0.,  0.,  0.,  0.,  0., 52.,  0.,
#          0.,  0.,  0.,  0., 59.,  0.,  0.,  0.,  0.,  0., 64.]),
#  array([0.  , 0.16, 0.32, 0.48, 0.64, 0.8 , 0.96, 1.12, 1.28, 1.44, 1.6 ,
#         1.76, 1.92, 2.08, 2.24, 2.4 , 2.56, 2.72, 2.88, 3.04, 3.2 , 3.36,
#         3.52, 3.68, 3.84, 4.  , 4.16, 4.32, 4.48, 4.64, 4.8 , 4.96, 5.12,
#         5.28, 5.44, 5.6 , 5.76, 5.92, 6.08, 6.24, 6.4 , 6.56, 6.72, 6.88,
#         7.04, 7.2 , 7.36, 7.52, 7.68, 7.84, 8.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### Generation of the "Little" Dataset

# %%
generator = Data_generator.Data_generator(number_data=160, n=25, noise=0, tr_size=0.63, test_size=0.25, wr=[0.2,0.7], hr=[0.2,0.7], flat=False,random_seed = 42)
data = generator.generate_data(return_data=True)
generator.save_data("data/2")
plt.hist(data[0][2], bins=50)
# Out:
# Data saved at :  data/2
# (array([ 9.,  0.,  0.,  0.,  0.,  0., 12.,  0.,  0.,  0.,  0.,  0., 13.,
#          0.,  0.,  0.,  0.,  0., 12.,  0.,  0.,  0.,  0.,  0.,  0., 12.,
#          0.,  0.,  0.,  0.,  0., 11.,  0.,  0.,  0.,  0.,  0., 14.,  0.,
#          0.,  0.,  0.,  0.,  8.,  0.,  0.,  0.,  0.,  0.,  9.]),
#  array([0.  , 0.16, 0.32, 0.48, 0.64, 0.8 , 0.96, 1.12, 1.28, 1.44, 1.6 ,
#         1.76, 1.92, 2.08, 2.24, 2.4 , 2.56, 2.72, 2.88, 3.04, 3.2 , 3.36,
#         3.52, 3.68, 3.84, 4.  , 4.16, 4.32, 4.48, 4.64, 4.8 , 4.96, 5.12,
#         5.28, 5.44, 5.6 , 5.76, 5.92, 6.08, 6.24, 6.4 , 6.56, 6.72, 6.88,
#         7.04, 7.2 , 7.36, 7.52, 7.68, 7.84, 8.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### Visualization of few examples:

# %%
data =  Data_generator.load_data("data/1",flat=False)
utils.vizualisation_example(data[0])
# Out:
# Data loaded from :  data/1

# %% [markdown]
# ## Read config file + train network

# %% [markdown]
# ### Dataset 1 (Training > 500) with config 1 (hidden >= 2):

# %%
config = utils.read_config_file("config/config_1.txt")

network = Network.Network(config)
network.init_weights()

# If we want to visualize the forward
#network.forward(network.X_train[0], network.y_train[0],True)

network.train(epochs=50)

network.visualize(False)
print("Test score:",network.test_score())
# Out:
# Data loaded from :  data/1
# Data flattened
# Training the network
# Epoch :  0  Train Loss :  2.0297868810969053
# Epoch :  1  Train Loss :  1.6738566805386164
# Epoch :  2  Train Loss :  1.3852259648869034
# Epoch :  3  Train Loss :  1.1732000555997537
# Epoch :  4  Train Loss :  1.0352446215397901
# Epoch :  5  Train Loss :  0.9574781899599605
# Epoch :  6  Train Loss :  0.9210592205110715
# Epoch :  7  Train Loss :  0.9089042348675821
# Epoch :  8  Train Loss :  0.908922257450568
# Epoch :  9  Train Loss :  0.9139407202839727
# Epoch :  10  Train Loss :  0.920260453085214
# Epoch :  11  Train Loss :  0.9262249572692779
# Epoch :  12  Train Loss :  0.9312409026491998
# Epoch :  13  Train Loss :  0.9352126871599867
# Epoch :  14  Train Loss :  0.938247820571912
# Epoch :  15  Train Loss :  0.9405153265441235
# Epoch :  16  Train Loss :  0.9421837846716882
# Epoch :  17  Train Loss :  0.9433982945424038
# Epoch :  18  Train Loss :  0.9442751839776221
# Epoch :  19  Train Loss :  0.944904049602466
# Epoch :  20  Train Loss :  0.9453522325135987
# Epoch :  21  Train Loss :  0.9456695409829384
# Epoch :  22  Train Loss :  0.9458924302474665
# Epoch :  23  Train Loss :  0.9460473909324029
# Epoch :  24  Train Loss :  0.9461535773783802
# Epoch :  25  Train Loss :  0.9462247915121531
# Epoch :  26  Train Loss :  0.9462709544284648
# Epoch :  27  Train Loss :  0.9462991854634049
# Epoch :  28  Train Loss :  0.9463145872989163
# Epoch :  29  Train Loss :  0.9463208141240723
# Epoch :  30  Train Loss :  0.9463204812677107
# Epoch :  31  Train Loss :  0.946315459764682
# Epoch :  32  Train Loss :  0.9463070877896553
# Epoch :  33  Train Loss :  0.9462963227971776
# Epoch :  34  Train Loss :  0.9462838510452566
# Epoch :  35  Train Loss :  0.9462701585459881
# Epoch :  36  Train Loss :  0.9462555950527661
# Epoch :  37  Train Loss :  0.9462404105836061
# Epoch :  38  Train Loss :  0.9462247838576995
# Epoch :  39  Train Loss :  0.9462088426262072
# Epoch :  40  Train Loss :  0.9461926782064721
# Epoch :  41  Train Loss :  0.9461763558717422
# Epoch :  42  Train Loss :  0.9461599222779848
# Epoch :  43  Train Loss :  0.9461434107726766
# Epoch :  44  Train Loss :  0.9461268451895948
# Epoch :  45  Train Loss :  0.94611024256141
# Epoch :  46  Train Loss :  0.9460936102624805
# Epoch :  47  Train Loss :  0.9460769375361117
# Epoch :  48  Train Loss :  0.9460602584727295
# Epoch :  49  Train Loss :  0.9460435779766708
# Test score: 0.9486601266187736

# %% [markdown]
# ### Dataset 1 with config 2 (no hidden layer):

# %%
config = utils.read_config_file("config/config_2.txt")

network = Network.Network(config)
network.init_weights()

# If we want to visualize the forward
#network.forward(network.X_train[0], network.y_train[0],True)

network.train(epochs=200)

network.visualize(False)
print("Test score:",network.test_score())
# Out:
# Data loaded from :  data/1
# Data flattened
# Training the network
# Epoch :  0  Train Loss :  4.305612710398875
# Epoch :  1  Train Loss :  2.600635038631507
# Epoch :  2  Train Loss :  2.450441932344564
# Epoch :  3  Train Loss :  2.3498011065394726
# Epoch :  4  Train Loss :  2.2526036789772617
# Epoch :  5  Train Loss :  2.1639718931701912
# Epoch :  6  Train Loss :  2.0844344274379574
# Epoch :  7  Train Loss :  2.0129350040767036
# Epoch :  8  Train Loss :  1.9482143536596042
# Epoch :  9  Train Loss :  1.8892848986136919
# Epoch :  10  Train Loss :  1.8353001821432942
# Epoch :  11  Train Loss :  1.7856410581403128
# Epoch :  12  Train Loss :  1.7397452690758581
# Epoch :  13  Train Loss :  1.6971876203953369
# Epoch :  14  Train Loss :  1.6576132044830414
# Epoch :  15  Train Loss :  1.6207139566131314
# Epoch :  16  Train Loss :  1.58621994547253
# Epoch :  17  Train Loss :  1.5539255965993308
# Epoch :  18  Train Loss :  1.5236027489249444
# Epoch :  19  Train Loss :  1.4950732919326015
# Epoch :  20  Train Loss :  1.468202019173329
# Epoch :  21  Train Loss :  1.4428497798857853
# Epoch :  22  Train Loss :  1.4188985702301924
# Epoch :  23  Train Loss :  1.3962362441906613
# Epoch :  24  Train Loss :  1.3747716756966954
# Epoch :  25  Train Loss :  1.3544145923215747
# Epoch :  26  Train Loss :  1.335084640142636
# Epoch :  27  Train Loss :  1.316708485872356
# Epoch :  28  Train Loss :  1.2992316332355378
# Epoch :  29  Train Loss :  1.282587084295156
# Epoch :  30  Train Loss :  1.266723088812626
# Epoch :  31  Train Loss :  1.2515879321787833
# Epoch :  32  Train Loss :  1.2371261578246229
# Epoch :  33  Train Loss :  1.2233131700423234
# Epoch :  34  Train Loss :  1.210096016037358
# Epoch :  35  Train Loss :  1.1974354265983969
# Epoch :  36  Train Loss :  1.1853046191753795
# Epoch :  37  Train Loss :  1.1736872261849411
# Epoch :  38  Train Loss :  1.1625530221661982
# Epoch :  39  Train Loss :  1.1518459465511723
# Epoch :  40  Train Loss :  1.141564172718435
# Epoch :  41  Train Loss :  1.1316829883138355
# Epoch :  42  Train Loss :  1.1221674024294406
# Epoch :  43  Train Loss :  1.1130094795367425
# Epoch :  44  Train Loss :  1.1041768640231964
# Epoch :  45  Train Loss :  1.095665247563324
# Epoch :  46  Train Loss :  1.0874564614196183
# Epoch :  47  Train Loss :  1.0795291013550947
# Epoch :  48  Train Loss :  1.0718673161576568
# Epoch :  49  Train Loss :  1.0644603769412126
# Epoch :  50  Train Loss :  1.0572983095288793
# Epoch :  51  Train Loss :  1.0503647118128432
# Epoch :  52  Train Loss :  1.0436545464344253
# Epoch :  53  Train Loss :  1.0371441237036279
# Epoch :  54  Train Loss :  1.0308380995730733
# Epoch :  55  Train Loss :  1.024718695035385
# Epoch :  56  Train Loss :  1.0187736118474553
# Epoch :  57  Train Loss :  1.013005027157858
# Epoch :  58  Train Loss :  1.0073937621846438
# Epoch :  59  Train Loss :  1.001940498354855
# Epoch :  60  Train Loss :  0.9966317787319188
# Epoch :  61  Train Loss :  0.9914632607427268
# Epoch :  62  Train Loss :  0.9864307005970054
# Epoch :  63  Train Loss :  0.9815215670579728
# Epoch :  64  Train Loss :  0.9767304088005272
# Epoch :  65  Train Loss :  0.972058986503206
# Epoch :  66  Train Loss :  0.9674966195033005
# Epoch :  67  Train Loss :  0.9630475089170278
# Epoch :  68  Train Loss :  0.9586952579493752
# Epoch :  69  Train Loss :  0.95445197431803
# Epoch :  70  Train Loss :  0.950292369500202
# Epoch :  71  Train Loss :  0.9462188988080649
# Epoch :  72  Train Loss :  0.942233362878449
# Epoch :  73  Train Loss :  0.9383371922627246
# Epoch :  74  Train Loss :  0.9345157928403339
# Epoch :  75  Train Loss :  0.9307716611642077
# Epoch :  76  Train Loss :  0.9270967636899127
# Epoch :  77  Train Loss :  0.9235002860901728
# Epoch :  78  Train Loss :  0.9199673989605355
# Epoch :  79  Train Loss :  0.9165037230071013
# Epoch :  80  Train Loss :  0.9131060950059122
# Epoch :  81  Train Loss :  0.9097684936763911
# Epoch :  82  Train Loss :  0.9064809742186872
# Epoch :  83  Train Loss :  0.9032561890023042
# Epoch :  84  Train Loss :  0.9000813320640825
# Epoch :  85  Train Loss :  0.896961978987701
# Epoch :  86  Train Loss :  0.8938994654017007
# Epoch :  87  Train Loss :  0.8908699669597016
# Epoch :  88  Train Loss :  0.8878938524441612
# Epoch :  89  Train Loss :  0.8849607744485551
# Epoch :  90  Train Loss :  0.8820627225157363
# Epoch :  91  Train Loss :  0.8792115208829732
# Epoch :  92  Train Loss :  0.8764031067759906
# Epoch :  93  Train Loss :  0.8736125819873949
# Epoch :  94  Train Loss :  0.870873574914987
# Epoch :  95  Train Loss :  0.8681669947108748
# Epoch :  96  Train Loss :  0.8654929661503853
# Epoch :  97  Train Loss :  0.8628701827338775
# Epoch :  98  Train Loss :  0.8602727347243175
# Epoch :  99  Train Loss :  0.857707474969896
# Epoch :  100  Train Loss :  0.8551829609277397
# Epoch :  101  Train Loss :  0.8526779678614964
# Epoch :  102  Train Loss :  0.850203661895546
# Epoch :  103  Train Loss :  0.8477574622260351
# Epoch :  104  Train Loss :  0.8453371285119018
# Epoch :  105  Train Loss :  0.8429507738525387
# Epoch :  106  Train Loss :  0.8405988208638974
# Epoch :  107  Train Loss :  0.8382627110211508
# Epoch :  108  Train Loss :  0.8359477061068321
# Epoch :  109  Train Loss :  0.8336630096730631
# Epoch :  110  Train Loss :  0.8313980815365222
# Epoch :  111  Train Loss :  0.8291651827073334
# Epoch :  112  Train Loss :  0.8269628586083997
# Epoch :  113  Train Loss :  0.8247754265107307
# Epoch :  114  Train Loss :  0.8226080484753687
# Epoch :  115  Train Loss :  0.8204682757351097
# Epoch :  116  Train Loss :  0.8183328220487357
# Epoch :  117  Train Loss :  0.8162303963752753
# Epoch :  118  Train Loss :  0.8141406881883801
# Epoch :  119  Train Loss :  0.8120790555217863
# Epoch :  120  Train Loss :  0.8100249809986145
# Epoch :  121  Train Loss :  0.8079900252247608
# Epoch :  122  Train Loss :  0.8059786468216769
# Epoch :  123  Train Loss :  0.8039953760407479
# Epoch :  124  Train Loss :  0.8020155926623864
# Epoch :  125  Train Loss :  0.8000704689616955
# Epoch :  126  Train Loss :  0.7981268828441827
# Epoch :  127  Train Loss :  0.7961947578975587
# Epoch :  128  Train Loss :  0.7942882876689075
# Epoch :  129  Train Loss :  0.7923991070570457
# Epoch :  130  Train Loss :  0.7905192164196525
# Epoch :  131  Train Loss :  0.7886608860293062
# Epoch :  132  Train Loss :  0.7868123695196506
# Epoch :  133  Train Loss :  0.7849695033233361
# Epoch :  134  Train Loss :  0.7831450421205021
# Epoch :  135  Train Loss :  0.7813496928549276
# Epoch :  136  Train Loss :  0.7795598457449187
# Epoch :  137  Train Loss :  0.777788000622476
# Epoch :  138  Train Loss :  0.7760322208969578
# Epoch :  139  Train Loss :  0.7742877252826009
# Epoch :  140  Train Loss :  0.7725594158944146
# Epoch :  141  Train Loss :  0.7708391238368333
# Epoch :  142  Train Loss :  0.7691352460294106
# Epoch :  143  Train Loss :  0.7674475043687712
# Epoch :  144  Train Loss :  0.7657833369594312
# Epoch :  145  Train Loss :  0.7641163624138865
# Epoch :  146  Train Loss :  0.7624579395725971
# Epoch :  147  Train Loss :  0.7608185826342247
# Epoch :  148  Train Loss :  0.7591822918607642
# Epoch :  149  Train Loss :  0.7575629266932401
# Epoch :  150  Train Loss :  0.7559647810361051
# Epoch :  151  Train Loss :  0.7543626290972211
# Epoch :  152  Train Loss :  0.7527895372315859
# Epoch :  153  Train Loss :  0.7512148246850022
# Epoch :  154  Train Loss :  0.7496536869390995
# Epoch :  155  Train Loss :  0.748120734574599
# Epoch :  156  Train Loss :  0.7465745922468463
# Epoch :  157  Train Loss :  0.7450428338654989
# Epoch :  158  Train Loss :  0.7435250709898316
# Epoch :  159  Train Loss :  0.7420196403412163
# Epoch :  160  Train Loss :  0.7405256985005613
# Epoch :  161  Train Loss :  0.7390442917735611
# Epoch :  162  Train Loss :  0.7375711465678741
# Epoch :  163  Train Loss :  0.7361105629789174
# Epoch :  164  Train Loss :  0.734661972002796
# Epoch :  165  Train Loss :  0.7332158516715179
# Epoch :  166  Train Loss :  0.7317700630192487
# Epoch :  167  Train Loss :  0.7303383625515638
# Epoch :  168  Train Loss :  0.728921457563609
# Epoch :  169  Train Loss :  0.7275174306583635
# Epoch :  170  Train Loss :  0.7261202667251102
# Epoch :  171  Train Loss :  0.724724160244592
# Epoch :  172  Train Loss :  0.72335922986579
# Epoch :  173  Train Loss :  0.7219855566213095
# Epoch :  174  Train Loss :  0.720630311978461
# Epoch :  175  Train Loss :  0.7192745591051812
# Epoch :  176  Train Loss :  0.717943855114113
# Epoch :  177  Train Loss :  0.7166028295472868
# Epoch :  178  Train Loss :  0.7152759055327922
# Epoch :  179  Train Loss :  0.7139668848623141
# Epoch :  180  Train Loss :  0.7126506647156968
# Epoch :  181  Train Loss :  0.7113526032482161
# Epoch :  182  Train Loss :  0.7100664372377049
# Epoch :  183  Train Loss :  0.708772811118163
# Epoch :  184  Train Loss :  0.7074973065868676
# Epoch :  185  Train Loss :  0.7062322225995219
# Epoch :  186  Train Loss :  0.7049707368347145
# Epoch :  187  Train Loss :  0.7037109032200711
# Epoch :  188  Train Loss :  0.7024734125688817
# Epoch :  189  Train Loss :  0.7012207931919963
# Epoch :  190  Train Loss :  0.6999994336256359
# Epoch :  191  Train Loss :  0.6987747552827049
# Epoch :  192  Train Loss :  0.6975614310896265
# Epoch :  193  Train Loss :  0.6963602875509785
# Epoch :  194  Train Loss :  0.695160972889432
# Epoch :  195  Train Loss :  0.6939658362227793
# Epoch :  196  Train Loss :  0.6927856325867926
# Epoch :  197  Train Loss :  0.6916148462943972
# Epoch :  198  Train Loss :  0.6904427023599622
# Epoch :  199  Train Loss :  0.6892735743638956
# Test score: 1.28947894746071

# %% [markdown]
# ### Dataset 2 (Little one) with config 3 (min 5 hidden layers):

# %%
config = utils.read_config_file("config/config_3.txt")

network = Network.Network(config)
network.init_weights()

# If we want to visualize the forward
#network.forward(network.X_train[0], network.y_train[0],True)

network.train(epochs=100)

network.visualize(False)
print("Test score:",network.test_score())
# Out:
# Data loaded from :  data/2
# Data flattened
# Training the network
# Epoch :  0  Train Loss :  3.7800511124157787
# Epoch :  1  Train Loss :  3.5873379994165067
# Epoch :  2  Train Loss :  3.398591757858414
# Epoch :  3  Train Loss :  3.2134503368297165
# Epoch :  4  Train Loss :  3.0317002509886777
# Epoch :  5  Train Loss :  2.8533672030705257
# Epoch :  6  Train Loss :  2.678787557904383
# Epoch :  7  Train Loss :  2.508645217277728
# Epoch :  8  Train Loss :  2.3439761758566804
# Epoch :  9  Train Loss :  2.186078188857579
# Epoch :  10  Train Loss :  2.0364071173927814
# Epoch :  11  Train Loss :  1.896411598321309
# Epoch :  12  Train Loss :  1.7673465746389991
# Epoch :  13  Train Loss :  1.6501231082619015
# Epoch :  14  Train Loss :  1.5452021719100406
# Epoch :  15  Train Loss :  1.4525326340074978
# Epoch :  16  Train Loss :  1.3716748605114553
# Epoch :  17  Train Loss :  1.3017962870176438
# Epoch :  18  Train Loss :  1.241856931656776
# Epoch :  19  Train Loss :  1.190754949467511
# Epoch :  20  Train Loss :  1.147344812798982
# Epoch :  21  Train Loss :  1.1105456425996354
# Epoch :  22  Train Loss :  1.0793764955001803
# Epoch :  23  Train Loss :  1.0529649413748416
# Epoch :  24  Train Loss :  1.0305560482055456
# Epoch :  25  Train Loss :  1.0115036549929213
# Epoch :  26  Train Loss :  0.9952662247168763
# Epoch :  27  Train Loss :  0.9813889264479496
# Epoch :  28  Train Loss :  0.9694936940774014
# Epoch :  29  Train Loss :  0.959266072511474
# Epoch :  30  Train Loss :  0.9504448922952804
# Epoch :  31  Train Loss :  0.9428131809163812
# Epoch :  32  Train Loss :  0.9361906605056768
# Epoch :  33  Train Loss :  0.930426783438782
# Epoch :  34  Train Loss :  0.9253958916034881
# Epoch :  35  Train Loss :  0.9209927654808628
# Epoch :  36  Train Loss :  0.9171289633395189
# Epoch :  37  Train Loss :  0.913729893190807
# Epoch :  38  Train Loss :  0.9107325153036967
# Epoch :  39  Train Loss :  0.9080835315173872
# Epoch :  40  Train Loss :  0.9057375094756811
# Epoch :  41  Train Loss :  0.9036556258951302
# Epoch :  42  Train Loss :  0.9018046880410874
# Epoch :  43  Train Loss :  0.9001561932232894
# Epoch :  44  Train Loss :  0.8986855674529061
# Epoch :  45  Train Loss :  0.8973715900715663
# Epoch :  46  Train Loss :  0.8961959359344769
# Epoch :  47  Train Loss :  0.8951426652265773
# Epoch :  48  Train Loss :  0.8941979197199389
# Epoch :  49  Train Loss :  0.8933495808575558
# Epoch :  50  Train Loss :  0.8925870426465239
# Epoch :  51  Train Loss :  0.8919010022568225
# Epoch :  52  Train Loss :  0.8912832892540206
# Epoch :  53  Train Loss :  0.8907267002397552
# Epoch :  54  Train Loss :  0.8902248679406535
# Epoch :  55  Train Loss :  0.8897721648372854
# Epoch :  56  Train Loss :  0.8893636030826036
# Epoch :  57  Train Loss :  0.8889947736541924
# Epoch :  58  Train Loss :  0.888661739644825
# Epoch :  59  Train Loss :  0.8883609501724024
# Epoch :  60  Train Loss :  0.8880892696017514
# Epoch :  61  Train Loss :  0.8878438756246038
# Epoch :  62  Train Loss :  0.8876222860277564
# Epoch :  63  Train Loss :  0.8874222488590976
# Epoch :  64  Train Loss :  0.8872417416446994
# Epoch :  65  Train Loss :  0.8870789455505121
# Epoch :  66  Train Loss :  0.8869322215046133
# Epoch :  67  Train Loss :  0.8868000881704079
# Epoch :  68  Train Loss :  0.8866812030160796
# Epoch :  69  Train Loss :  0.8865743784951411
# Epoch :  70  Train Loss :  0.8864785247591764
# Epoch :  71  Train Loss :  0.8863926550169
# Epoch :  72  Train Loss :  0.8863158754957712
# Epoch :  73  Train Loss :  0.886247373145479
# Epoch :  74  Train Loss :  0.8861864106888655
# Epoch :  75  Train Loss :  0.8861323179663187
# Epoch :  76  Train Loss :  0.8860844853284959
# Epoch :  77  Train Loss :  0.8860423577429374
# Epoch :  78  Train Loss :  0.8860054295300235
# Epoch :  79  Train Loss :  0.8859732394860316
# Epoch :  80  Train Loss :  0.8859453668773043
# Epoch :  81  Train Loss :  0.8859214280581742
# Epoch :  82  Train Loss :  0.8859010727294269
# Epoch :  83  Train Loss :  0.8858839798756396
# Epoch :  84  Train Loss :  0.8858698564417681
# Epoch :  85  Train Loss :  0.8858584342760054
# Epoch :  86  Train Loss :  0.8858494681025485
# Epoch :  87  Train Loss :  0.8858427333228596
# Epoch :  88  Train Loss :  0.8858380242145342
# Epoch :  89  Train Loss :  0.8858351521849979
# Epoch :  90  Train Loss :  0.885833944693508
# Epoch :  91  Train Loss :  0.885834243387374
# Epoch :  92  Train Loss :  0.8858359031147873
# Epoch :  93  Train Loss :  0.8858387907753387
# Epoch :  94  Train Loss :  0.8858427843039743
# Epoch :  95  Train Loss :  0.8858477661054769
# Epoch :  96  Train Loss :  0.8858536333537245
# Epoch :  97  Train Loss :  0.8858602978811817
# Epoch :  98  Train Loss :  0.8858676732856039
# Epoch :  99  Train Loss :  0.8858756789682587
# Test score: 0.8959467115748074
