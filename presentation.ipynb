# %% [markdown]
# # Presentation Notebook

# %% [markdown]
# ## import

# %%
import sys
sys.path.append("sources")

from Doodler import *
import Data_generator
import utils
import Network

import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data generator

# %% [markdown]
# ### Generation of the "big" dataset

# %%
generator = Data_generator.Data_generator(number_data=800, n=25, noise=0, tr_size=0.63, test_size=0.25, wr=[0.2,0.7], hr=[0.2,0.7], flat=False,random_seed = 42)
data = generator.generate_data(return_data=True)
generator.save_data("data/1")
plt.hist(data[0][2], bins=50)
# Out:
# Data saved at :  data/1
# (array([46.,  0.,  0.,  0.,  0.,  0., 61.,  0.,  0.,  0.,  0.,  0., 44.,
#          0.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0.,  0.,  0.,  0., 61.,
#          0.,  0.,  0.,  0.,  0., 67.,  0.,  0.,  0.,  0.,  0., 52.,  0.,
#          0.,  0.,  0.,  0., 59.,  0.,  0.,  0.,  0.,  0., 64.]),
#  array([0.  , 0.16, 0.32, 0.48, 0.64, 0.8 , 0.96, 1.12, 1.28, 1.44, 1.6 ,
#         1.76, 1.92, 2.08, 2.24, 2.4 , 2.56, 2.72, 2.88, 3.04, 3.2 , 3.36,
#         3.52, 3.68, 3.84, 4.  , 4.16, 4.32, 4.48, 4.64, 4.8 , 4.96, 5.12,
#         5.28, 5.44, 5.6 , 5.76, 5.92, 6.08, 6.24, 6.4 , 6.56, 6.72, 6.88,
#         7.04, 7.2 , 7.36, 7.52, 7.68, 7.84, 8.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### Generation of the "Little" Dataset

# %%
generator = Data_generator.Data_generator(number_data=160, n=25, noise=0, tr_size=0.63, test_size=0.25, wr=[0.2,0.7], hr=[0.2,0.7], flat=False,random_seed = 42)
data = generator.generate_data(return_data=True)
generator.save_data("data/2")
plt.hist(data[0][2], bins=50)
# Out:
# Data saved at :  data/2
# (array([ 9.,  0.,  0.,  0.,  0.,  0., 12.,  0.,  0.,  0.,  0.,  0., 13.,
#          0.,  0.,  0.,  0.,  0., 12.,  0.,  0.,  0.,  0.,  0.,  0., 12.,
#          0.,  0.,  0.,  0.,  0., 11.,  0.,  0.,  0.,  0.,  0., 14.,  0.,
#          0.,  0.,  0.,  0.,  8.,  0.,  0.,  0.,  0.,  0.,  9.]),
#  array([0.  , 0.16, 0.32, 0.48, 0.64, 0.8 , 0.96, 1.12, 1.28, 1.44, 1.6 ,
#         1.76, 1.92, 2.08, 2.24, 2.4 , 2.56, 2.72, 2.88, 3.04, 3.2 , 3.36,
#         3.52, 3.68, 3.84, 4.  , 4.16, 4.32, 4.48, 4.64, 4.8 , 4.96, 5.12,
#         5.28, 5.44, 5.6 , 5.76, 5.92, 6.08, 6.24, 6.4 , 6.56, 6.72, 6.88,
#         7.04, 7.2 , 7.36, 7.52, 7.68, 7.84, 8.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### Visualization of few examples:

# %%
data =  Data_generator.load_data("data/1",flat=False)
utils.vizualisation_example(data[0])
# Out:
# Data loaded from :  data/1

# %% [markdown]
# ## Read config file + train network

# %% [markdown]
# ### Dataset 1 (Training > 500) with config 1 (hidden >= 2):

# %%
config = utils.read_config_file("config/config_1.txt")

network = Network.Network(config)
network.init_weights()

# If we want to visualize the forward
#network.forward(network.X_train[0], network.y_train[0],True)

network.train(epochs=50)

network.visualize(False)
print("Test score:",network.test_score())
# Out:
# Data loaded from :  data/1
# Data flattened
# Training the network
# Epoch :  0  Train Loss :  3.864703134946492
# Epoch :  1  Train Loss :  2.1717540441886825
# Epoch :  2  Train Loss :  1.7384245333897943
# Epoch :  3  Train Loss :  1.630924283991656
# Epoch :  4  Train Loss :  1.5953313041882717
# Epoch :  5  Train Loss :  1.5579691250980563
# Epoch :  6  Train Loss :  1.5259825855345748
# Epoch :  7  Train Loss :  1.4965585965763994
# Epoch :  8  Train Loss :  1.4702316949415082
# Epoch :  9  Train Loss :  1.446513549140415
# Epoch :  10  Train Loss :  1.4252308120763282
# Epoch :  11  Train Loss :  1.406099358622557
# Epoch :  12  Train Loss :  1.3888767854575756
# Epoch :  13  Train Loss :  1.3733292503475487
# Epoch :  14  Train Loss :  1.3592461123863766
# Epoch :  15  Train Loss :  1.3464286850107732
# Epoch :  16  Train Loss :  1.334715293249127
# Epoch :  17  Train Loss :  1.3239530605988798
# Epoch :  18  Train Loss :  1.3140131579622298
# Epoch :  19  Train Loss :  1.3047859734410514
# Epoch :  20  Train Loss :  1.296193222699874
# Epoch :  21  Train Loss :  1.2881434790988113
# Epoch :  22  Train Loss :  1.2805835889991986
# Epoch :  23  Train Loss :  1.2734512660891675
# Epoch :  24  Train Loss :  1.2667010763128923
# Epoch :  25  Train Loss :  1.2602967788533659
# Epoch :  26  Train Loss :  1.2542007584597885
# Epoch :  27  Train Loss :  1.248394159742229
# Epoch :  28  Train Loss :  1.2428455419423532
# Epoch :  29  Train Loss :  1.2375311225377283
# Epoch :  30  Train Loss :  1.2324332185368616
# Epoch :  31  Train Loss :  1.227546234489536
# Epoch :  32  Train Loss :  1.2228404314587968
# Epoch :  33  Train Loss :  1.2183168135539697
# Epoch :  34  Train Loss :  1.213955773951068
# Epoch :  35  Train Loss :  1.2097546317685293
# Epoch :  36  Train Loss :  1.205695252460703
# Epoch :  37  Train Loss :  1.2017743165107417
# Epoch :  38  Train Loss :  1.1979857056038883
# Epoch :  39  Train Loss :  1.1943214502549382
# Epoch :  40  Train Loss :  1.1907740791222041
# Epoch :  41  Train Loss :  1.1873382676229058
# Epoch :  42  Train Loss :  1.1840058335335
# Epoch :  43  Train Loss :  1.180781335552072
# Epoch :  44  Train Loss :  1.1776507091542345
# Epoch :  45  Train Loss :  1.174616707528041
# Epoch :  46  Train Loss :  1.1716660055091752
# Epoch :  47  Train Loss :  1.1688049049207165
# Epoch :  48  Train Loss :  1.1660237096437251
# Epoch :  49  Train Loss :  1.1633198372275002
# Test score: 1.3237956603827694

# %% [markdown]
# ### Dataset 1 with config 2 (no hidden layer):

# %%
config = utils.read_config_file("config/config_2.txt")

network = Network.Network(config)
network.init_weights()

# If we want to visualize the forward
#network.forward(network.X_train[0], network.y_train[0],True)

network.train(epochs=200)

network.visualize(False)
print("Test score:",network.test_score())
# Out:
# Data loaded from :  data/1
# Data flattened
# Training the network
# Epoch :  0  Train Loss :  3.5758431581346453
# Epoch :  1  Train Loss :  2.454051970324151
# Epoch :  2  Train Loss :  2.329694039034214
# Epoch :  3  Train Loss :  2.2258951455093965
# Epoch :  4  Train Loss :  2.127127633738563
# Epoch :  5  Train Loss :  2.0396959726437363
# Epoch :  6  Train Loss :  1.9632237743359782
# Epoch :  7  Train Loss :  1.8958468217928017
# Epoch :  8  Train Loss :  1.8357705035925287
# Epoch :  9  Train Loss :  1.7816671881754054
# Epoch :  10  Train Loss :  1.7325280297738193
# Epoch :  11  Train Loss :  1.687603784037418
# Epoch :  12  Train Loss :  1.6463193605325401
# Epoch :  13  Train Loss :  1.608205344009732
# Epoch :  14  Train Loss :  1.5729053057259417
# Epoch :  15  Train Loss :  1.5401096330080823
# Epoch :  16  Train Loss :  1.5095372741454367
# Epoch :  17  Train Loss :  1.4809852834856476
# Epoch :  18  Train Loss :  1.4542471997602233
# Epoch :  19  Train Loss :  1.4291674614552003
# Epoch :  20  Train Loss :  1.4055994302074464
# Epoch :  21  Train Loss :  1.3834166918220543
# Epoch :  22  Train Loss :  1.3624931041236545
# Epoch :  23  Train Loss :  1.3427451281644822
# Epoch :  24  Train Loss :  1.3240680970782965
# Epoch :  25  Train Loss :  1.3063822112258356
# Epoch :  26  Train Loss :  1.2896187013649252
# Epoch :  27  Train Loss :  1.2737090819031187
# Epoch :  28  Train Loss :  1.2585871785169778
# Epoch :  29  Train Loss :  1.244200185524539
# Epoch :  30  Train Loss :  1.2305030698551493
# Epoch :  31  Train Loss :  1.2174575343659144
# Epoch :  32  Train Loss :  1.2050124405590794
# Epoch :  33  Train Loss :  1.193133158685453
# Epoch :  34  Train Loss :  1.181782050883171
# Epoch :  35  Train Loss :  1.1709228123674031
# Epoch :  36  Train Loss :  1.16052898376161
# Epoch :  37  Train Loss :  1.1505636697542143
# Epoch :  38  Train Loss :  1.1409943631955681
# Epoch :  39  Train Loss :  1.131823454856237
# Epoch :  40  Train Loss :  1.123017676875635
# Epoch :  41  Train Loss :  1.1145557525903282
# Epoch :  42  Train Loss :  1.1064131808415574
# Epoch :  43  Train Loss :  1.0985822196804016
# Epoch :  44  Train Loss :  1.0910329898356927
# Epoch :  45  Train Loss :  1.0837517850762195
# Epoch :  46  Train Loss :  1.076716630749646
# Epoch :  47  Train Loss :  1.069932673460455
# Epoch :  48  Train Loss :  1.0633638399668397
# Epoch :  49  Train Loss :  1.0570208564430017
# Epoch :  50  Train Loss :  1.050879528268019
# Epoch :  51  Train Loss :  1.0449207736681583
# Epoch :  52  Train Loss :  1.0391559322051662
# Epoch :  53  Train Loss :  1.0335643822447873
# Epoch :  54  Train Loss :  1.0281373797396813
# Epoch :  55  Train Loss :  1.0228754750077145
# Epoch :  56  Train Loss :  1.0177511699559403
# Epoch :  57  Train Loss :  1.0127740068124962
# Epoch :  58  Train Loss :  1.0079327351149978
# Epoch :  59  Train Loss :  1.0032125178622964
# Epoch :  60  Train Loss :  0.9986106987889743
# Epoch :  61  Train Loss :  0.9941254834728264
# Epoch :  62  Train Loss :  0.9897471888374997
# Epoch :  63  Train Loss :  0.9854763228608652
# Epoch :  64  Train Loss :  0.9813067566313401
# Epoch :  65  Train Loss :  0.9772340154432418
# Epoch :  66  Train Loss :  0.9732506094493305
# Epoch :  67  Train Loss :  0.9693584595211101
# Epoch :  68  Train Loss :  0.9655387483538633
# Epoch :  69  Train Loss :  0.9617957218822566
# Epoch :  70  Train Loss :  0.9581353694474459
# Epoch :  71  Train Loss :  0.9545477592429358
# Epoch :  72  Train Loss :  0.9510294990952974
# Epoch :  73  Train Loss :  0.9475746343670621
# Epoch :  74  Train Loss :  0.9441874387480249
# Epoch :  75  Train Loss :  0.9408555398528816
# Epoch :  76  Train Loss :  0.9375758193062264
# Epoch :  77  Train Loss :  0.9343554909640934
# Epoch :  78  Train Loss :  0.9311994477543145
# Epoch :  79  Train Loss :  0.9280816799334454
# Epoch :  80  Train Loss :  0.9250147386409848
# Epoch :  81  Train Loss :  0.9219974748625291
# Epoch :  82  Train Loss :  0.9190161709172998
# Epoch :  83  Train Loss :  0.9160903892843536
# Epoch :  84  Train Loss :  0.9132112346757291
# Epoch :  85  Train Loss :  0.9103396130079193
# Epoch :  86  Train Loss :  0.9075253428174282
# Epoch :  87  Train Loss :  0.9047529271471544
# Epoch :  88  Train Loss :  0.9020092367076833
# Epoch :  89  Train Loss :  0.8993190619271438
# Epoch :  90  Train Loss :  0.8966604979913949
# Epoch :  91  Train Loss :  0.8940302521599318
# Epoch :  92  Train Loss :  0.8914276840468194
# Epoch :  93  Train Loss :  0.8888505472750771
# Epoch :  94  Train Loss :  0.8863016090329543
# Epoch :  95  Train Loss :  0.8837992780139879
# Epoch :  96  Train Loss :  0.8813158671016879
# Epoch :  97  Train Loss :  0.8788715612952955
# Epoch :  98  Train Loss :  0.8764409309833449
# Epoch :  99  Train Loss :  0.8740408364901996
# Epoch :  100  Train Loss :  0.8716608172051633
# Epoch :  101  Train Loss :  0.8693047472114284
# Epoch :  102  Train Loss :  0.8669712088451106
# Epoch :  103  Train Loss :  0.864661667759967
# Epoch :  104  Train Loss :  0.8623790341279094
# Epoch :  105  Train Loss :  0.8601047047395945
# Epoch :  106  Train Loss :  0.8578630812867516
# Epoch :  107  Train Loss :  0.8556374687151509
# Epoch :  108  Train Loss :  0.8534287234115389
# Epoch :  109  Train Loss :  0.8512465498672408
# Epoch :  110  Train Loss :  0.849083461539708
# Epoch :  111  Train Loss :  0.8469407433369567
# Epoch :  112  Train Loss :  0.8448215694455082
# Epoch :  113  Train Loss :  0.8427106865436245
# Epoch :  114  Train Loss :  0.8406156576262855
# Epoch :  115  Train Loss :  0.8385441152307566
# Epoch :  116  Train Loss :  0.8364904744414224
# Epoch :  117  Train Loss :  0.8344611495196254
# Epoch :  118  Train Loss :  0.8324425325879338
# Epoch :  119  Train Loss :  0.8304397829518535
# Epoch :  120  Train Loss :  0.8284425568095527
# Epoch :  121  Train Loss :  0.8264705654889357
# Epoch :  122  Train Loss :  0.8245012591565899
# Epoch :  123  Train Loss :  0.8225547030065623
# Epoch :  124  Train Loss :  0.8206250870808578
# Epoch :  125  Train Loss :  0.8187162724609657
# Epoch :  126  Train Loss :  0.8168145382678784
# Epoch :  127  Train Loss :  0.8149325598647109
# Epoch :  128  Train Loss :  0.813049362448372
# Epoch :  129  Train Loss :  0.8111872131161545
# Epoch :  130  Train Loss :  0.8093397851875931
# Epoch :  131  Train Loss :  0.807502711551129
# Epoch :  132  Train Loss :  0.8056848429478944
# Epoch :  133  Train Loss :  0.8038777833847314
# Epoch :  134  Train Loss :  0.8020879580991281
# Epoch :  135  Train Loss :  0.8003032502034106
# Epoch :  136  Train Loss :  0.7985361275448374
# Epoch :  137  Train Loss :  0.7967788517341209
# Epoch :  138  Train Loss :  0.7950303460727252
# Epoch :  139  Train Loss :  0.7933006773641715
# Epoch :  140  Train Loss :  0.791572849397746
# Epoch :  141  Train Loss :  0.7898620092228907
# Epoch :  142  Train Loss :  0.7881629605817966
# Epoch :  143  Train Loss :  0.7864799654228873
# Epoch :  144  Train Loss :  0.7847978922091178
# Epoch :  145  Train Loss :  0.7831329564138191
# Epoch :  146  Train Loss :  0.7814670212281984
# Epoch :  147  Train Loss :  0.7798269217345214
# Epoch :  148  Train Loss :  0.7781909260320953
# Epoch :  149  Train Loss :  0.7765692829745034
# Epoch :  150  Train Loss :  0.7749568737944047
# Epoch :  151  Train Loss :  0.7733456429267905
# Epoch :  152  Train Loss :  0.7717594612035006
# Epoch :  153  Train Loss :  0.7701756029139414
# Epoch :  154  Train Loss :  0.7686024573777968
# Epoch :  155  Train Loss :  0.7670475471970344
# Epoch :  156  Train Loss :  0.7655093671052793
# Epoch :  157  Train Loss :  0.763971590844199
# Epoch :  158  Train Loss :  0.7624329287358824
# Epoch :  159  Train Loss :  0.760918064179151
# Epoch :  160  Train Loss :  0.7594132049337925
# Epoch :  161  Train Loss :  0.7579047226881352
# Epoch :  162  Train Loss :  0.7564210788180957
# Epoch :  163  Train Loss :  0.7549404313558986
# Epoch :  164  Train Loss :  0.7534639316225558
# Epoch :  165  Train Loss :  0.7520017066100515
# Epoch :  166  Train Loss :  0.750545091265897
# Epoch :  167  Train Loss :  0.7490936310232642
# Epoch :  168  Train Loss :  0.7476529235965459
# Epoch :  169  Train Loss :  0.7462208731357495
# Epoch :  170  Train Loss :  0.7448094401849106
# Epoch :  171  Train Loss :  0.7433923573382781
# Epoch :  172  Train Loss :  0.7419821456548883
# Epoch :  173  Train Loss :  0.7405834954349026
# Epoch :  174  Train Loss :  0.7391994465708133
# Epoch :  175  Train Loss :  0.7378148638995743
# Epoch :  176  Train Loss :  0.7364451229092702
# Epoch :  177  Train Loss :  0.7350929083646239
# Epoch :  178  Train Loss :  0.7337406080001104
# Epoch :  179  Train Loss :  0.7323991688097712
# Epoch :  180  Train Loss :  0.7310657321349153
# Epoch :  181  Train Loss :  0.729737716943565
# Epoch :  182  Train Loss :  0.728419606540409
# Epoch :  183  Train Loss :  0.7271093290365143
# Epoch :  184  Train Loss :  0.7257999621773986
# Epoch :  185  Train Loss :  0.7245138884892125
# Epoch :  186  Train Loss :  0.7232289840706727
# Epoch :  187  Train Loss :  0.7219403231247233
# Epoch :  188  Train Loss :  0.7206692224326813
# Epoch :  189  Train Loss :  0.7193994240454872
# Epoch :  190  Train Loss :  0.7181451179204541
# Epoch :  191  Train Loss :  0.7168947084797037
# Epoch :  192  Train Loss :  0.7156498126329703
# Epoch :  193  Train Loss :  0.7144125085839831
# Epoch :  194  Train Loss :  0.7131953264989034
# Epoch :  195  Train Loss :  0.7119617786033398
# Epoch :  196  Train Loss :  0.7107540916566226
# Epoch :  197  Train Loss :  0.7095441445813766
# Epoch :  198  Train Loss :  0.7083420991219438
# Epoch :  199  Train Loss :  0.7071402583477887
# Test score: 1.2632993434755877

# %% [markdown]
# ### Dataset 2 (Little one) with config 3 (min 5 hidden layers):

# %%
config = utils.read_config_file("config/config_3.txt")

network = Network.Network(config)
network.init_weights()

# If we want to visualize the forward
#network.forward(network.X_train[0], network.y_train[0],True)

network.train(epochs=100)

network.visualize(False)
print("Test score:",network.test_score())
# Out:
# Data loaded from :  data/2
# Data flattened
# Training the network
# Epoch :  0  Train Loss :  3.8724654773561453
# Epoch :  1  Train Loss :  3.662265204318171
# Epoch :  2  Train Loss :  3.4543638039769475
# Epoch :  3  Train Loss :  3.2489983330186543
# Epoch :  4  Train Loss :  3.046734000701816
# Epoch :  5  Train Loss :  2.847734297002278
# Epoch :  6  Train Loss :  2.6528605391895055
# Epoch :  7  Train Loss :  2.4636528761570515
# Epoch :  8  Train Loss :  2.2821345382962495
# Epoch :  9  Train Loss :  2.1105963374870713
# Epoch :  10  Train Loss :  1.9511256845797533
# Epoch :  11  Train Loss :  1.805268015047194
# Epoch :  12  Train Loss :  1.6740584115924673
# Epoch :  13  Train Loss :  1.5580076268176108
# Epoch :  14  Train Loss :  1.4569296763238428
# Epoch :  15  Train Loss :  1.370027824384743
# Epoch :  16  Train Loss :  1.2960869173946452
# Epoch :  17  Train Loss :  1.2336586499027817
# Epoch :  18  Train Loss :  1.1812227616693536
# Epoch :  19  Train Loss :  1.1373057088626966
# Epoch :  20  Train Loss :  1.1005506863052983
# Epoch :  21  Train Loss :  1.0697698923291954
# Epoch :  22  Train Loss :  1.0439452773756994
# Epoch :  23  Train Loss :  1.0222209914688987
# Epoch :  24  Train Loss :  1.003887784996277
# Epoch :  25  Train Loss :  0.9883612322103406
# Epoch :  26  Train Loss :  0.9751627322305318
# Epoch :  27  Train Loss :  0.9639003453296806
# Epoch :  28  Train Loss :  0.9542528275629246
# Epoch :  29  Train Loss :  0.9459575226273933
# Epoch :  30  Train Loss :  0.9387988311865152
# Epoch :  31  Train Loss :  0.9325992419172482
# Epoch :  32  Train Loss :  0.9272121395858952
# Epoch :  33  Train Loss :  0.9225159950154753
# Epoch :  34  Train Loss :  0.9184097001166082
# Epoch :  35  Train Loss :  0.9148087740692887
# Epoch :  36  Train Loss :  0.9116424201166656
# Epoch :  37  Train Loss :  0.9088510977260256
# Epoch :  38  Train Loss :  0.9063844640020506
# Epoch :  39  Train Loss :  0.9041998307560759
# Epoch :  40  Train Loss :  0.9022608696142622
# Epoch :  41  Train Loss :  0.9005365558696908
# Epoch :  42  Train Loss :  0.8990003029417403
# Epoch :  43  Train Loss :  0.8976292505643201
# Epoch :  44  Train Loss :  0.8964036916508786
# Epoch :  45  Train Loss :  0.8953065730679235
# Epoch :  46  Train Loss :  0.89432309906443
# Epoch :  47  Train Loss :  0.8934403962381557
# Epoch :  48  Train Loss :  0.8926472334241677
# Epoch :  49  Train Loss :  0.891933786712067
# Epoch :  50  Train Loss :  0.8912914416718248
# Epoch :  51  Train Loss :  0.8907126263619211
# Epoch :  52  Train Loss :  0.8901906690682009
# Epoch :  53  Train Loss :  0.8897196791777384
# Epoch :  54  Train Loss :  0.8892944466994492
# Epoch :  55  Train Loss :  0.8889103504211161
# Epoch :  56  Train Loss :  0.8885632814522916
# Epoch :  57  Train Loss :  0.8882495928368163
# Epoch :  58  Train Loss :  0.8879660277356852
# Epoch :  59  Train Loss :  0.8877096775381385
# Epoch :  60  Train Loss :  0.8874779414727112
# Epoch :  61  Train Loss :  0.8872684878405613
# Epoch :  62  Train Loss :  0.8870792243883627
# Epoch :  63  Train Loss :  0.8869082715510069
# Epoch :  64  Train Loss :  0.8867539380570822
# Epoch :  65  Train Loss :  0.8866147000566985
# Epoch :  66  Train Loss :  0.8864891828133014
# Epoch :  67  Train Loss :  0.8863761446130803
# Epoch :  68  Train Loss :  0.8862744625965412
# Epoch :  69  Train Loss :  0.8861831202596927
# Epoch :  70  Train Loss :  0.8861011964084626
# Epoch :  71  Train Loss :  0.8860278553805202
# Epoch :  72  Train Loss :  0.8859623383745938
# Epoch :  73  Train Loss :  0.8859039557493651
# Epoch :  74  Train Loss :  0.8858520801614667
# Epoch :  75  Train Loss :  0.8858061383922555
# Epoch :  76  Train Loss :  0.8857656124492844
# Epoch :  77  Train Loss :  0.8857300278301201
# Epoch :  78  Train Loss :  0.8856989515752539
# Epoch :  79  Train Loss :  0.8856719883665752
# Epoch :  80  Train Loss :  0.8856487770270768
# Epoch :  81  Train Loss :  0.885628987376531
# Epoch :  82  Train Loss :  0.885612317417113
# Epoch :  83  Train Loss :  0.885598490723928
# Epoch :  84  Train Loss :  0.8855872542529883
# Epoch :  85  Train Loss :  0.8855783761955456
# Epoch :  86  Train Loss :  0.8855716441246223
# Epoch :  87  Train Loss :  0.885566863301521
# Epoch :  88  Train Loss :  0.8855638551424747
# Epoch :  89  Train Loss :  0.885562455828898
# Epoch :  90  Train Loss :  0.8855625150465695
# Epoch :  91  Train Loss :  0.8855638948407052
# Epoch :  92  Train Loss :  0.8855664685753176
# Epoch :  93  Train Loss :  0.8855701199865206
# Epoch :  94  Train Loss :  0.8855747423205621
# Epoch :  95  Train Loss :  0.8855802375483401
# Epoch :  96  Train Loss :  0.8855865156490402
# Epoch :  97  Train Loss :  0.885593493956297
# Epoch :  98  Train Loss :  0.8856010965609704
# Epoch :  99  Train Loss :  0.88560925376523
# Test score: 0.8967223352695386
